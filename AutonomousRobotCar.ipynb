# %%
from ultralytics import YOLO

# %%
model = YOLO('./yolov8s.pt')

# %%
model.train(model='./yolov8s.pt',\
            data='./datasets/VaseBookShoes/VaseBookShoes.yaml', \
            epochs=100, batch=16,\
            imgsz = 640, patience = 100)
# Out:
# Ultralytics YOLOv8.0.29 🚀 Python-3.9.16 torch-1.13.1+cu117 CUDA:0 (Quadro M1200, 4096MiB)
# ...
